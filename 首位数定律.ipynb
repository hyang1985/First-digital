# %%
import time
import random
import math

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置-黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
# Out:
# In D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
#理论值
theriotical_distribution=np.array([math.log10(1+1/i) for i in range(1,10)])
theriotical_distribution
# Out:
# array([0.30103   , 0.17609126, 0.12493874, 0.09691001, 0.07918125,
#        0.06694679, 0.05799195, 0.05115252, 0.04575749])

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1, 1, 1)
ax=plt.bar(range(1,10),theriotical_distribution)
#sns.distplot(df_new['总价'])

# %%
test=pd.read_csv("worldpopulation.csv")

# %%
test=test[test!='..']

# %%
test=test.dropna()

# %%
test
# Out:
#                                  Series Name     Series Code  \
# 0                          Population, total     SP.POP.TOTL
# 1                          Population, total     SP.POP.TOTL
# 2                          Population, total     SP.POP.TOTL
# 3                          Population, total     SP.POP.TOTL
# 4                          Population, total     SP.POP.TOTL
# ...                                      ...             ...
# 11057  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 11059  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 11061  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 11063  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 11065  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
#
#              Country Name Country Code      2000 [YR2000]       2001 [YR2001]  \
# 0             Afghanistan          AFG           20779957            21606992
# 1                 Albania          ALB            3089027             3060173
# 2                 Algeria          DZA           31042238            31451513
# 3          American Samoa          ASM              57816               58496
# 4                 Andorra          AND              65390               67344
# ...                   ...          ...                ...                 ...
# 11057             Uruguay          URY   4.76382472733248    4.35934065217274
# 11059             Vanuatu          VUT   2.53768844221106    3.57755452095076
# 11061             Vietnam          VNM  -1.71033727851113  -0.431544511728152
# 11063  West Bank and Gaza          PSE   2.79819892435757    1.22278475878899
# 11065              Zambia          ZMB   26.0304117888121    21.3937821792546
#
#           2002 [YR2002]     2003 [YR2003]     2004 [YR2004]     2005 [YR2005]  \
# 0              22600774          23680871          24726689          25654274
# 1               3051010           3039616           3026939           3011487
# 2              31855110          32264159          32692153          33149720
# 3                 59077             59495             59684             59557
# 4                 70048             73180             76250             78871
# ...                 ...               ...               ...               ...
# 11057  13.9724725913516  19.3797301743994  9.15760507540996   4.6992773903564
# 11059  1.96356754199194  3.01624129930396  1.41891891891891  1.19920053297802
# 11061  3.83082838168469  3.23464817293924  7.75494748709602   8.2845724312867
# 11063  5.70951585976628  4.40303221730885  3.00417498638594  4.10725070715932
# 11065  22.2333446430947  21.4015783901995  17.9677891087286   18.324439701174
#
#           2006 [YR2006]     2007 [YR2007]     2008 [YR2008]     2009 [YR2009]  \
# 0              26433058          27100542          27722281          28394806
# 1               2992547           2970017           2947314           2927519
# 2              33641007          34166976          34730604          35333882
# 3                 59109             58367             57490             56675
# 4                 80995             82682             83860             84461
# ...                 ...               ...               ...               ...
# 11057  6.39764974385121  8.11464561179318  7.87707374730889  7.06221874388572
# 11059   2.0408163265306  3.93548387096775  4.84171322160149  4.29706572955357
# 11061  7.41801715108469  8.34444889773838  23.1154483474477  6.71698269988629
# 11063   3.8423412562478  1.85974379351109  9.88999788691853  2.75393485083151
# 11065  9.01957247226486  10.6573496000153  12.4455793463192  13.3952546325895
#
#           2010 [YR2010]      2011 [YR2011]     2012 [YR2012]  \
# 0              29185511           30117411          31161378
# 1               2913021            2905195           2900401
# 2              35977451           36661438          37383899
# 3                 56084              55755             55669
# 4                 84454              83748             82427
# ...                 ...                ...               ...
# 11057  6.69870886978135   8.09283206302989  8.09776580573602
# 11059   2.7626946947735  0.873793104781058  1.34740362877658
# 11061  9.20746648778418   18.6777322770706  9.09470339557193
# 11063  3.74915727597098    2.8772435849594  2.77908768282493
# 11065  8.50176133365265   6.42939681072336  6.57589970757695
#
#           2013 [YR2013]      2014 [YR2014]      2015 [YR2015]
# 0              32269592           33370804           34413603
# 1               2895092            2889104            2880703
# 2              38140135           38923688           39728020
# 3                 55717              55791              55806
# 4                 80770              79213              77993
# ...                 ...                ...                ...
# 11057  8.57513504005394   8.87735333229828   8.66626987079337
# 11059  1.45893371757928  0.798863838096904   2.48326875660446
# 11061  6.59267475899191   4.08455446637622  0.631200905175718
# 11063  1.72439933626923   1.73298510037451   1.43161145810472
# 11065  6.97767605490317   7.80687553566328   10.1105928909618
#
# [6478 rows x 20 columns]

# %%
#2015年人口
population=test[test['Series Name']=='Population, total']
population['2014 [YR2014]']=population['2014 [YR2014]'].apply(float)
# Out:
# D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#2014年人口
population=test[test['Series Name']=='Population, total']
population['2015 [YR2015]']=population['2015 [YR2015]'].apply(float)
# Out:
# D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
theriotical_distribution=np.array([math.log10(1+1/i) for i in range(1,10)])
real_distribution=population['2015 [YR2015]']
real_distribution=(real_distribution.apply(lambda x:str(x)[0]).value_counts()/real_distribution.apply(lambda x:str(x)[0]).value_counts().sum()).reindex(['1','2','3','4','5','6','7','8','9'])
fig=plt.figure(figsize=(15,12))
ax = fig.add_subplot(1, 1, 1)
x = np.arange(1,10)
width = 0.35
rects1 = ax.bar(x - width/2, theriotical_distribution, width, label='理论值')
rects2 = ax.bar(x + width/2, real_distribution, width, label='实际值')
ax.set_xticks(x)
ax.legend()
for p in rects1:
    height = p.get_height()
    ax.text(x=p.get_x() + p.get_width() / 2, y=height+0.005,
    s="{:.2%}".format(height),
    ha='center')
for p in rects2:
    height = p.get_height()
    ax.text(x=p.get_x() + p.get_width() / 2, y=height+0.005,
    s="{:.2%}".format(height),
    ha='center')
plt.show()

# %%
def plot_distribution(real_distribution):
    real_distribution=(real_distribution.apply(lambda x:str(x)[0]).value_counts()/real_distribution.apply(lambda x:str(x)[0]).value_counts().sum()).reindex(['1','2','3','4','5','6','7','8','9'])
    ax=plt.figure(figsize=(15,12)).add_subplot(1, 1, 1)
    x = np.arange(1,10)
    width = 0.35
    rects1 = ax.bar(x - width/2, theriotical_distribution, width, label='理论值')
    rects2 = ax.bar(x + width/2, real_distribution, width, label='实际值')
    ax.set_xticks(x)
    ax.legend()
    for p in rects1:
        height = p.get_height()
        ax.text(x=p.get_x() + p.get_width() / 2, y=height+0.005,
        s="{:.2%}".format(height),
        ha='center')
    for p in rects2:
        height = p.get_height()
        ax.text(x=p.get_x() + p.get_width() / 2, y=height+0.005,
        s="{:.2%}".format(height),
        ha='center')
    plt.show()

# %%
#国土面积
Surfacearea=test[test['Series Name']=='Surface area (sq. km)']
Surfacearea['2015 [YR2015]']=Surfacearea['2015 [YR2015]'].apply(float)
# Out:
# D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plot_distribution(Surfacearea['2015 [YR2015]'])

# %%
#GDP
GDP=test[test['Series Name']=='GDP (current US$)']
GDP['2014 [YR2014]']=GDP['2014 [YR2014]'].apply(float)
# Out:
# D:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plot_distribution(GDP['2014 [YR2014]'])

# %%
GDP
# Out:
#             Series Name     Series Code         Country Name Country Code  \
# 5643  GDP (current US$)  NY.GDP.MKTP.CD              Albania          ALB
# 5644  GDP (current US$)  NY.GDP.MKTP.CD              Algeria          DZA
# 5646  GDP (current US$)  NY.GDP.MKTP.CD              Andorra          AND
# 5647  GDP (current US$)  NY.GDP.MKTP.CD               Angola          AGO
# 5648  GDP (current US$)  NY.GDP.MKTP.CD  Antigua and Barbuda          ATG
# ...                 ...             ...                  ...          ...
# 5853  GDP (current US$)  NY.GDP.MKTP.CD              Vietnam          VNM
# 5855  GDP (current US$)  NY.GDP.MKTP.CD   West Bank and Gaza          PSE
# 5856  GDP (current US$)  NY.GDP.MKTP.CD          Yemen, Rep.          YEM
# 5857  GDP (current US$)  NY.GDP.MKTP.CD               Zambia          ZMB
# 5858  GDP (current US$)  NY.GDP.MKTP.CD             Zimbabwe          ZWE
#
#          2000 [YR2000]     2001 [YR2001]     2002 [YR2002]     2003 [YR2003]  \
# 5643  3480355188.60063  3922099470.97313  4348070165.19261  5611492282.86582
# 5644  54790379458.8877  54744725765.7191  56760318215.3036  67863841333.4195
# 5646  1429049198.45218  1546926174.49664  1755910031.99699  2361726862.30248
# 5647  9129634978.33773  8936063723.20121   15285594828.418   17812705294.325
# 5648   826370370.37037  800481481.481481  814381481.481481  856396296.296296
# ...                ...               ...               ...               ...
# 5853  31172518403.3162  32685198735.3053  35064105500.8344  39552513316.0734
# 5855        4313600000        4003700000        3555800000        3968000000
# 5856  9652436179.64605  9861560094.74009  10694628091.6726  11777966673.3897
# 5857  3600683039.73254  4094480988.11931  4193845678.17033  4901839731.26571
# 5858        6689957600        6777384700        6342116400        5727591800
#
#          2004 [YR2004]     2005 [YR2005]     2006 [YR2006]     2007 [YR2007]  \
# 5643   7184681398.5698  8052075642.10781  8896073938.31407  10677321490.3807
# 5644  85332581188.6107  103198251003.394  117027321306.159  134977125918.571
# 5646  2894921777.99851  3159905484.39249    3456442102.622  3952600602.24473
# 5647  23552052407.5488  36970918699.2523   52381006892.038   65266452081.386
# 5648   919729629.62963  1022962962.96296  1157662962.96296  1312759259.25926
# ...                ...               ...               ...               ...
# 5853  45427854693.2554  57633255618.2731  66371664817.0436  77414425532.2452
# 5855        4603100000        5125700000        5348300000        5815700000
# 5856  13872791658.5487  16746344766.2044  19061978586.1278  21650532264.2322
# 5857  6221077674.77871  8331870169.14977  12756858899.2812  14056957976.2648
# 5858        5805598400        5755215200        5443896500        5291950100
#
#          2008 [YR2008]     2009 [YR2009]     2010 [YR2010]     2011 [YR2011]  \
# 5643  12881354103.8398  12044223352.5413  11926928505.5231  12890765324.2256
# 5644  171000653424.751  137211049535.152   161207310515.42  200013038488.906
# 5646  4085630584.44412  3674409558.21061  3449966856.68832  3629203786.19154
# 5647  88538611205.1433   70307163678.238  83799496611.2004  111789686464.441
# 5648  1370070370.37037  1228329629.62963        1148700000  1137637037.03704
# ...                ...               ...               ...               ...
# 5853  99130304099.1274  106014659770.222  115931749697.241  135539438559.709
# 5855        7310400000        8085700000        9681500000       11186100000
# 5856  26910851361.7555  25130274124.2525   30906749533.221   32726417212.348
# 5857  17910858637.9048  15328342303.9575  20265559483.8548  23459515275.5776
# 5858        4415702800        9665793300       12041655200       14101920300
#
#          2012 [YR2012]     2013 [YR2013]  2014 [YR2014]     2015 [YR2015]
# 5643  12319830252.4768  12776217194.7928   1.322814e+10  11386846319.1589
# 5644  209058991952.125  209755003250.664   2.138100e+11  165979173991.026
# 5646  3188808942.56713  3193704343.20627   3.271808e+09  2789870187.50693
# 5647  128052853643.106  136709862831.194   1.457122e+11  116193649124.151
# 5648  1199948148.14815  1181448148.14815   1.249733e+09  1336692592.59259
# ...                ...               ...            ...               ...
# 5853  155820001920.492  171222025117.381   1.862047e+11  193241108709.536
# 5855       12208400000       13515500000   1.398970e+10       13972400000
# 5856  35401341663.0425  40415235701.9871   4.322859e+10  42445102386.6049
# 5857   25503060420.026  28037239462.7142   2.714102e+10  21251216798.7762
# 5858       17114849900       19091020000   1.949552e+10       19963120600
#
# [194 rows x 20 columns]

# %%
test['Series Name'].value_counts()
# Out:
# Population, total                                                              216
# Population growth (annual %)                                                   216
# Surface area (sq. km)                                                          215
# Forest area (sq. km)                                                           210
# Net barter terms of trade index (2000 = 100)                                   201
# Fertility rate, total (births per woman)                                       199
# Life expectancy at birth, total (years)                                        199
# GDP (current US$)                                                              194
# Adolescent fertility rate (births per 1,000 women ages 15-19)                  194
# GDP per capita (current US$)                                                   194
# Mortality rate, under-5 (per 1,000 live births)                                193
# CO2 emissions (metric tons per capita)                                         191
# Mobile cellular subscriptions (per 100 people)                                 190
# Immunization, measles (% of children ages 12-23 months)                        189
# Foreign direct investment, net inflows (BoP, current US$)                      188
# GDP growth (annual %)                                                          186
# Inflation, GDP deflator (annual %)                                             185
# Merchandise trade (% of GDP)                                                   183
# GNI, PPP (current international $)                                             178
# GNI per capita, PPP (current international $)                                  178
# GNI, Atlas method (current US$)                                                175
# GNI per capita, Atlas method (current US$)                                     175
# Agriculture, forestry, and fishing, value added (% of GDP)                     175
# Industry (including construction), value added (% of GDP)                      173
# Imports of goods and services (% of GDP)                                       168
# Exports of goods and services (% of GDP)                                       168
# Inflation, consumer prices (annual %)                                          159
# Gross capital formation (% of GDP)                                             157
# Foreign direct investment, net (BoP, current US$)                              141
# Net ODA received per capita (current US$)                                      134
# Personal remittances, paid (current US$)                                       133
# Military expenditure (% of GDP)                                                123
# Prevalence of HIV, total (% of population ages 15-49)                          122
# External debt stocks, total (DOD, current US$)                                 116
# Total debt service (% of GNI)                                                  110
# Revenue, excluding grants (% of GDP)                                            69
# School enrollment, secondary (% gross)                                          57
# School enrollment, primary and secondary (gross), gender parity index (GPI)     48
# Market capitalization of listed domestic companies (% of GDP)                   42
# Primary completion rate, total (% of relevant age group)                        41
# Births attended by skilled health staff (% of total)                            39
# Energy use (kg of oil equivalent per capita)                                    34
# Income share held by lowest 20%                                                 15
# Poverty headcount ratio at national poverty lines (% of population)              3
# Electric power consumption (kWh per capita)                                      1
# Contraceptive prevalence, any methods (% of women ages 15-49)                    1
# Name: Series Name, dtype: int64

# %%
"{:.2%}".format(0.32)
# Out:
# '32.00%'

# %%
sh600519=pd.read_excel("600519.SH-财务摘要.xls")
sh600519.index=sh600519['贵州茅台[600519.SH] - 财务摘要']
sh600519=sh600519.loc[:,'2021-06-30':]
sh600519
# Out:
#                          2021-06-30   2021-03-31   2020-12-31   2020-09-30  \
# 贵州茅台[600519.SH] - 财务摘要
# 报告期                              中报          一季报           年报          三季报
# 数据来源                           合并报表         合并报表         合并报表         合并报表
#     利润表摘要                       NaN          NaN          NaN          NaN
#         营业总收入           5.07216e+06  2.80647e+06  9.79932e+06  6.95749e+06
#             同比(%)             11.15        10.93        10.29         9.55
# ...                             ...          ...          ...          ...
#         员工总数(人)               29031        29031        29031        27005
# 显示币种                            CNY          CNY          CNY          CNY
# 原始币种                            CNY          CNY          CNY          CNY
# 转换汇率                              1            1            1            1
# 利率类型                           期末汇率         期末汇率         期末汇率         期末汇率
#
#                          2020-06-30   2020-03-31   2019-12-31   2019-09-30  \
# 贵州茅台[600519.SH] - 财务摘要
# 报告期                              中报          一季报           年报          三季报
# 数据来源                           合并报表         合并报表         合并报表         合并报表
#     利润表摘要                       NaN          NaN          NaN          NaN
#         营业总收入           4.56344e+06  2.52985e+06  8.88543e+06  6.35087e+06
#             同比(%)             10.84        12.54         15.1        15.53
# ...                             ...          ...          ...          ...
#         员工总数(人)               27005        27005        27005        26568
# 显示币种                            CNY          CNY          CNY          CNY
# 原始币种                            CNY          CNY          CNY          CNY
# 转换汇率                              1            1            1            1
# 利率类型                           期末汇率         期末汇率         期末汇率         期末汇率
#
#                          2019-06-30   2019-03-31  ... 2004-03-31 2003-12-31  \
# 贵州茅台[600519.SH] - 财务摘要                            ...
# 报告期                              中报          一季报  ...        一季报         年报
# 数据来源                           合并报表         合并报表  ...       合并报表       合并报表
#     利润表摘要                       NaN          NaN  ...        NaN        NaN
#         营业总收入           4.11727e+06  2.24805e+06  ...    85343.2     240102
#             同比(%)              16.8        22.21  ...      16.29      30.85
# ...                             ...          ...  ...        ...        ...
#         员工总数(人)               26568        26568  ...       4405       4405
# 显示币种                            CNY          CNY  ...        CNY        CNY
# 原始币种                            CNY          CNY  ...        CNY        CNY
# 转换汇率                              1            1  ...          1          1
# 利率类型                           期末汇率         期末汇率  ...       期末汇率       期末汇率
#
#                        2003-09-30 2003-06-30 2003-03-31 2002-12-31 2002-09-30  \
# 贵州茅台[600519.SH] - 财务摘要
# 报告期                           三季报         中报        一季报         年报        三季报
# 数据来源                         合并报表       合并报表       合并报表       合并报表       合并报表
#     利润表摘要                     NaN        NaN        NaN        NaN        NaN
#         营业总收入              155274     100905    73388.9     183490     136389
#             同比(%)           13.85       5.59       2.21       13.4        NaN
# ...                           ...        ...        ...        ...        ...
#         员工总数(人)              3951       3951       3951       3951       3526
# 显示币种                          CNY        CNY        CNY        CNY        CNY
# 原始币种                          CNY        CNY        CNY        CNY        CNY
# 转换汇率                            1          1          1          1          1
# 利率类型                         期末汇率       期末汇率       期末汇率       期末汇率       期末汇率
#
#                        2002-06-30 2002-03-31 2001-12-31
# 贵州茅台[600519.SH] - 财务摘要
# 报告期                            中报        一季报         年报
# 数据来源                         合并报表       合并报表       合并报表
#     利润表摘要                     NaN        NaN        NaN
#         营业总收入             95565.4    71801.5     161805
#             同比(%)            9.36        NaN      45.25
# ...                           ...        ...        ...
#         员工总数(人)              3526       3526       3526
# 显示币种                          CNY        CNY        CNY
# 原始币种                          CNY        CNY        CNY
# 转换汇率                            1          1          1
# 利率类型                         期末汇率       期末汇率       期末汇率
#
# [82 rows x 79 columns]

# %%
sh600519.index
# Out:
# Index(['报告期', '数据来源', '    利润表摘要', '        营业总收入', '            同比(%)',
#        '        营业总成本', '        营业利润', '            同比(%)', '        利润总额',
#        '            同比(%)', '        净利润', '            同比(%)',
#        '        归属母公司股东的净利润', '            同比(%)', '        非经常性损益',
#        '        扣非后归属母公司股东的净利润', '            同比(%)', '        研发支出',
#        '        EBIT', '        EBITDA', '    资产负债表摘要', '        流动资产',
#        '        固定资产', '        长期股权投资', '        资产总计', '            同比(%)',
#        '        流动负债', '        非流动负债', '        负债合计', '            同比(%)',
#        '        股东权益', '        归属母公司股东的权益', '            增长率',
#        '        资本公积金', '        盈余公积金', '        未分配利润', '    现金流量表摘要',
#        '        销售商品提供劳务收到的现金', '        经营活动现金净流量', '        购建固定无形长期资产支付的现金',
#        '        投资支付的现金', '        投资活动现金净流量', '        吸收投资收到的现金',
#        '        取得借款收到的现金', '        筹资活动现金净流量', '        现金净增加额',
#        '        期末现金余额', '        折旧与摊销', '    关键比率', '        ROE(摊薄)(%)',
#        '        ROE(加权)(%)', '        扣非后ROE(摊薄)(%)', '        ROA(%)',
#        '        ROIC(%)', '        销售毛利率(%)', '        销售净利率(%)',
#        '        EBIT Margin(%)', '        EBITDA Margin(%)',
#        '        资产负债率(%)', '        资产周转率(倍)', '        销售商品和劳务收到现金/营业收入(%)',
#        '    每股指标', '        EPS(基本)', '        EPS(稀释)', '        EPS(摊薄)',
#        '        扣非后EPS(基本)', '        每股净资产BPS', '        每股净资产BPS(转股后)',
#        '        每股销售额SPS', '        每股经营现金流OCFPS', '        每股现金净流量CFPS',
#        '        每股企业自由现金流', '        P/E(TTM)', '        P/E(LYR)',
#        '        P/B(MRQ)', '        P/S(TTM)', '    其他', '        员工总数(人)',
#        '显示币种', '原始币种', '转换汇率', '利率类型'],
#       dtype='object', name='贵州茅台[600519.SH] - 财务摘要')

# %%
theriotical_distribution=np.array([math.log10(1+1/i) for i in range(1,10)])
#real_distribution=(real_distribution.apply(lambda x:str(x)[0]).value_counts()/real_distribution.apply(lambda x:str(x)[0]).value_counts().sum()).reindex(['1','2','3','4','5','6','7','8','9'])
fig,axs = plt.subplots(2, 2,figsize=(20,16))
attr_list=['        营业总收入','        营业利润','        资产总计','        员工总数(人)']
titles=['营业总收入','营业利润','资产总计','员工总数(人)']
j=0
for col in range(2):
    for row in range(2):
        ax = axs[row, col]
        x = np.arange(1,10)
        real_distribution=sh600519.loc[attr_list[j]]
        real_distribution=(real_distribution.apply(lambda x:str(x)[0]).value_counts()/real_distribution.apply(lambda x:str(x)[0]).value_counts().sum()).reindex(['1','2','3','4','5','6','7','8','9'])
        #fig=plt.figure(figsize=(15,12))
        width = 0.35
        rects1 = ax.bar(x - width/2, theriotical_distribution, width, label='理论值')
        rects2 = ax.bar(x + width/2, real_distribution, width, label='实际值')
        ax.set_xticks(x)
        ax.set_title(titles[j])
        ax.legend()
        for p in rects1:
            height = p.get_height()
            ax.text(x=p.get_x() + p.get_width() / 2-0.1, y=height+0.005,
            s="{:.1%}".format(height),
            ha='center')
        for p in rects2:
            height = p.get_height()
            ax.text(x=p.get_x() + p.get_width() / 2+0.1, y=height+0.005,
            s="{:.1%}".format(height),
            ha='center')
        j=j+1

# %%
sh601398=pd.read_excel("601398.SH-财务摘要.xls")
sh601398.index=sh601398['工商银行[601398.SH] - 财务摘要']
sh601398=sh601398.loc[:,'2021-06-30':]
sh601398
# Out:
#                        2021-03-31 2020-12-31 2020-09-30 2020-06-30 2020-03-31  \
# 工商银行[601398.SH] - 财务摘要
# 报告期                           一季报         年报        三季报         中报        一季报
# 数据来源                         合并报表       合并报表       合并报表       合并报表       合并报表
#     利润表摘要                     NaN        NaN        NaN        NaN        NaN
#         营业总收入            23419100   88266500   66569300   44845600   22697900
#             同比(%)            3.18       3.18        2.9       1.25      -3.62
# ...                           ...        ...        ...        ...        ...
# 转换汇率                            1          1          1          1          1
# 利率类型                         期末汇率       期末汇率       期末汇率       期末汇率       期末汇率
# NaN                           NaN        NaN        NaN        NaN        NaN
# NaN                           NaN        NaN        NaN        NaN        NaN
# 数据来源：Wind                     NaN        NaN        NaN        NaN        NaN
#
#                        2019-12-31 2019-09-30 2019-06-30 2019-03-31 2018-12-31  \
# 工商银行[601398.SH] - 财务摘要
# 报告期                            年报        三季报         中报        一季报         年报
# 数据来源                         合并报表       合并报表       合并报表       合并报表       合并报表
#     利润表摘要                     NaN        NaN        NaN        NaN        NaN
#         营业总收入            85516400   64694200   44291500   23550100   77378900
#             同比(%)           10.52      12.11      14.32      19.42       6.51
# ...                           ...        ...        ...        ...        ...
# 转换汇率                            1          1          1          1          1
# 利率类型                         期末汇率       期末汇率       期末汇率       期末汇率       期末汇率
# NaN                           NaN        NaN        NaN        NaN        NaN
# NaN                           NaN        NaN        NaN        NaN        NaN
# 数据来源：Wind                     NaN        NaN        NaN        NaN        NaN
#
#                         ... 2007-09-30 2007-06-30 2007-03-31 2006-12-31  \
# 工商银行[601398.SH] - 财务摘要  ...
# 报告期                     ...        三季报         中报        一季报         年报
# 数据来源                    ...       合并报表       合并报表       合并报表       合并报表
#     利润表摘要               ...        NaN        NaN        NaN        NaN
#         营业总收入           ...   18237400   11649200    5452000   17888900
#             同比(%)       ...      38.48      36.11        NaN      10.17
# ...                     ...        ...        ...        ...        ...
# 转换汇率                    ...          1          1          1          1
# 利率类型                    ...       期末汇率       期末汇率       期末汇率       期末汇率
# NaN                     ...        NaN        NaN        NaN        NaN
# NaN                     ...        NaN        NaN        NaN        NaN
# 数据来源：Wind               ...        NaN        NaN        NaN        NaN
#
#                        2006-09-30 2006-06-30 2005-12-31 2005-06-30 2004-12-31  \
# 工商银行[601398.SH] - 财务摘要
# 报告期                           三季报         中报         年报         中报         年报
# 数据来源                         合并报表       合并报表       合并报表       合并报表       合并报表
#     利润表摘要                     NaN        NaN        NaN        NaN        NaN
#         营业总收入            13169300    8466900   16237800    7649000   13934200
#             同比(%)             NaN      10.69      16.53        NaN      12.29
# ...                           ...        ...        ...        ...        ...
# 转换汇率                            1          1          1          1          1
# 利率类型                         期末汇率       期末汇率       期末汇率       期末汇率       期末汇率
# NaN                           NaN        NaN        NaN        NaN        NaN
# NaN                           NaN        NaN        NaN        NaN        NaN
# 数据来源：Wind                     NaN        NaN        NaN        NaN        NaN
#
#                        2003-12-31
# 工商银行[601398.SH] - 财务摘要
# 报告期                            年报
# 数据来源                         合并报表
#     利润表摘要                     NaN
#         营业总收入            12408700
#             同比(%)             NaN
# ...                           ...
# 转换汇率                            1
# 利率类型                         期末汇率
# NaN                           NaN
# NaN                           NaN
# 数据来源：Wind                     NaN
#
# [85 rows x 64 columns]

# %%
theriotical_distribution=np.array([math.log10(1+1/i) for i in range(1,10)])
#real_distribution=(real_distribution.apply(lambda x:str(x)[0]).value_counts()/real_distribution.apply(lambda x:str(x)[0]).value_counts().sum()).reindex(['1','2','3','4','5','6','7','8','9'])
fig,axs = plt.subplots(2, 2,figsize=(20,16))
attr_list=['        营业总收入','        营业利润','        资产总计','        员工总数(人)']
titles=['营业总收入','营业利润','资产总计','员工总数(人)']
j=0
for col in range(2):
    for row in range(2):
        ax = axs[row, col]
        x = np.arange(1,10)
        real_distribution=sh601398.loc[attr_list[j]]
        real_distribution=(real_distribution.apply(lambda x:str(x)[0]).value_counts()/real_distribution.apply(lambda x:str(x)[0]).value_counts().sum()).reindex(['1','2','3','4','5','6','7','8','9'])
        #fig=plt.figure(figsize=(15,12))
        width = 0.35
        rects1 = ax.bar(x - width/2, theriotical_distribution, width, label='理论值')
        rects2 = ax.bar(x + width/2, real_distribution, width, label='实际值')
        ax.set_xticks(x)
        ax.set_title(titles[j])
        ax.legend()
        for p in rects1:
            height = p.get_height()
            ax.text(x=p.get_x() + p.get_width() / 2-0.1, y=height+0.005,
            s="{:.1%}".format(height),
            ha='center')
        for p in rects2:
            height = p.get_height()
            ax.text(x=p.get_x() + p.get_width() / 2+0.1, y=height+0.005,
            s="{:.1%}".format(height),
            ha='center')
        j=j+1
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
wd=pd.read_excel("万得平台所有数据.xls")

# %%
wd['营业收入\n[报告期] 2021一季\n[报表类型] 合并报表\n[单位] 元']
# Out:
# 0       4.178800e+10
# 1       6.226410e+10
# 2       3.653115e+07
# 3       4.816156e+07
# 4       9.182869e+08
#             ...
# 4447    2.371487e+08
# 4448    1.481466e+08
# 4449    7.259496e+09
# 4450    7.291961e+09
# 4451    1.778577e+09
# Name: 营业收入\n[报告期] 2021一季\n[报表类型] 合并报表\n[单位] 元, Length: 4452, dtype: float64

# %%
wd.columns
# Out:
# Index(['证券代码', '证券简称', '营业收入\n[报告期] 2021一季\n[报表类型] 合并报表\n[单位] 元',
#        '营业利润\n[报告期] 2021一季\n[报表类型] 合并报表\n[单位] 元',
#        '资产总计\n[报告期] 2021一季\n[报表类型] 合并报表\n[单位] 元', '员工总数\n[交易日期] 2021-03-31'],
#       dtype='object')

# %%
theriotical_distribution=np.array([math.log10(1+1/i) for i in range(1,10)])
#real_distribution=(real_distribution.apply(lambda x:str(x)[0]).value_counts()/real_distribution.apply(lambda x:str(x)[0]).value_counts().sum()).reindex(['1','2','3','4','5','6','7','8','9'])
fig,axs = plt.subplots(2, 2,figsize=(20,16))
attr_list=['营业收入\n[报告期] 2021一季\n[报表类型] 合并报表\n[单位] 元',
           '营业利润\n[报告期] 2021一季\n[报表类型] 合并报表\n[单位] 元',
           '资产总计\n[报告期] 2021一季\n[报表类型] 合并报表\n[单位] 元',
           '员工总数\n[交易日期] 2021-03-31']
titles=['营业总收入','营业利润','资产总计','员工总数(人)']
j=0
for col in range(2):
    for row in range(2):
        ax = axs[row, col]
        x = np.arange(1,10)
        real_distribution=wd.loc[:,attr_list[j]]
        real_distribution=(real_distribution.apply(lambda x:str(x)[0]).value_counts()/real_distribution.apply(lambda x:str(x)[0]).value_counts().sum()).reindex(['1','2','3','4','5','6','7','8','9'])
        #fig=plt.figure(figsize=(15,12))
        width = 0.35
        rects1 = ax.bar(x - width/2, theriotical_distribution, width, label='理论值')
        rects2 = ax.bar(x + width/2, real_distribution, width, label='实际值')
        ax.set_xticks(x)
        ax.set_title(titles[j])
        ax.legend()
        for p in rects1:
            height = p.get_height()
            ax.text(x=p.get_x() + p.get_width() / 2-0.1, y=height+0.005,
            s="{:.1%}".format(height),
            ha='center')
        for p in rects2:
            height = p.get_height()
            ax.text(x=p.get_x() + p.get_width() / 2+0.1, y=height+0.005,
            s="{:.1%}".format(height),
            ha='center')
        j=j+1

# %%
wd.loc[:,attr_list[j]]
# Out:
# 0       4.178800e+10
# 1       6.226410e+10
# 2       3.653115e+07
# 3       4.816156e+07
# 4       9.182869e+08
#             ...
# 4447    2.371487e+08
# 4448    1.481466e+08
# 4449    7.259496e+09
# 4450    7.291961e+09
# 4451    1.778577e+09
# Name: 营业收入\n[报告期] 2021一季\n[报表类型] 合并报表\n[单位] 元, Length: 4452, dtype: float64
